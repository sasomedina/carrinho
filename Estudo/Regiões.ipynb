# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import datetime
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_csv(r'carrinho_abandonado_csv.csv', parse_dates=True)
pd.options.display.max_columns = 103
display(df.head())
# Out:
#    Unnamed: 0    status  channel isSubscription reserva aliasId  \
# 0           0  RESERVED      APP           True   AE45H   WA04F
# 1           1  RESERVED  COCKPIT           True  ZA117G   BK28G
# 2           2  RESERVED     SITE           True   ZD43G   LY32F
# 3           3   EXPIRED      APP           True  ZL309G   WA04F
# 4           4   EXPIRED     SITE          False   ZJ37G   GP37G
#
#                           name     cidade                bairro  \
# 0  SP-HOBC 0307 - Housi Duplex  Sao Paulo               Jardins
# 1  SP-VNHM 1213A - Housi Prime  Sao Paulo          Vila Mariana
# 2  SP-VNQT 1408 - Housi Duplex  Sao Paulo  Condado - Itaim Bibi
# 3  SP-HOBC 0307 - Housi Duplex  Sao Paulo               Jardins
# 4   SP-HOFL 0601 - Housi Prime  Sao Paulo  Condado - Itaim Bibi
#
#                      rua        CEP Id_parceiro                 parceiro1  \
# 0        Rua Bela Cintra  1415005.0       HOUSI  Housi gestão patrimonial
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28505 entries, 0 to 28546
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      28505 non-null  int64
#  1   status          28505 non-null  object
#  2   channel         28505 non-null  object
#  3   isSubscription  28505 non-null  object
#  4   reserva         28503 non-null  object
#  5   aliasId         28056 non-null  object
#  6   name            28056 non-null  object
#  7   cidade          8522 non-null   object
#  8   bairro          8522 non-null   object
#  9   rua             9043 non-null   object
#  10  CEP             9163 non-null   float64
#  11  Id_parceiro     28505 non-null  object
#  12  parceiro1       28505 non-null  object
#  13  parceiro2       28505 non-null  object
#  14  criacao         28505 non-null  object
#  15  entrada         28505 non-null  object
#  16  saida           28505 non-null  object
# ...

# %%
df['criacao2'] = pd.to_datetime(df['criacao2'])

# %%
df[['criacao2']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28505 entries, 0 to 28546
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   criacao2  28505 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 1.4 MB

# %%
df.head()
# Out:
#    Unnamed: 0    status  channel isSubscription reserva aliasId  \
# 0           0  RESERVED      APP           True   AE45H   WA04F
# 1           1  RESERVED  COCKPIT           True  ZA117G   BK28G
# 2           2  RESERVED     SITE           True   ZD43G   LY32F
# 3           3   EXPIRED      APP           True  ZL309G   WA04F
# 4           4   EXPIRED     SITE          False   ZJ37G   GP37G
#
#                           name     cidade                bairro  \
# 0  SP-HOBC 0307 - Housi Duplex  São Paulo               Jardins
# 1  SP-VNHM 1213A - Housi Prime  São Paulo          Vila Mariana
# 2  SP-VNQT 1408 - Housi Duplex  São Paulo  Condado - Itaim Bibi
# 3  SP-HOBC 0307 - Housi Duplex  São Paulo               Jardins
# 4   SP-HOFL 0601 - Housi Prime  São Paulo  Condado - Itaim Bibi
#
#                      rua        CEP Id_parceiro                 parceiro1  \
# 0        Rua Bela Cintra  1415005.0       HOUSI  Housi gestão patrimonial
# ...

# %%
df['cidade'].unique()
# Out:
# array(['Sao Paulo', 'São Paulo', 'Flamengo', 'Rio de Janeiro',
#        'Porto Alegre', 'Barueri', 'Fortaleza', 'Guarulhos',
#        'Florianopolis', 'Foz do Iguaçu', 'Campinas', 'Belo Horizonte',
#        'Curitiba', 'Santo André', 'São José do Rio Preto', 'Recife',
#        'Copacabana', 'Goiânia', 'Ubatuba', 'Armação Dos Búzios',
#        'Joao Pessoa', 'Salvador', 'Botafogo', 'Cabo Frio', nan],
#       dtype=object)

# %%
df = df.replace({'Sao Paulo': 'São Paulo', 'Flamengo': 'Rio de Janeiro', 'Botafogo': 'Rio de Janeiro', 'Copacabana': 'Rio de Janeiro'})

# %%
df['cidade'].unique()
# Out:
# array(['São Paulo', 'Rio de Janeiro', 'Porto Alegre', 'Barueri',
#        'Fortaleza', 'Guarulhos', 'Florianopolis', 'Foz do Iguaçu',
#        'Campinas', 'Belo Horizonte', 'Curitiba', 'Santo André',
#        'São José do Rio Preto', 'Recife', 'Goiânia', 'Ubatuba',
#        'Armação Dos Búzios', 'Joao Pessoa', 'Salvador', 'Cabo Frio', nan],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# Unnamed: 0            0
# status            11352
# channel           11352
# isSubscription    11352
# reserva           11355
# aliasId           11844
# name              11844
# cidade            31378
# bairro            31378
# rua               30857
# CEP               30737
# Id_parceiro       11352
# parceiro1         11352
# parceiro2         11352
# criacao           11353
# entrada           11353
# saida             11353
# guest_name        11395
# guest_surname     11395
# guest_email       11395
# cost_total        11354
# cost_gross        11354
# cost_net          11354
# cupom_name        34561
# cupom_tipo        34560
# cupom_amount      34560
# sellerPerson      39151
# criacao2          11353
# dtype: int64

# %%
df = df[df['guest_email'].notna()]
df.isna().sum()
# Out:
# Unnamed: 0            0
# status                0
# channel               0
# isSubscription        0
# reserva               2
# aliasId             449
# name                449
# cidade            19983
# bairro            19983
# rua               19462
# CEP               19342
# Id_parceiro           0
# parceiro1             0
# parceiro2             0
# criacao               0
# entrada               0
# saida                 0
# guest_name            0
# guest_surname         0
# guest_email           0
# cost_total            1
# cost_gross            1
# cost_net              1
# cupom_name        23171
# cupom_tipo        23170
# cupom_amount      23170
# sellerPerson      27756
# criacao2              0
# dtype: int64

# %%
df.shape
# Out:
# (28505, 28)

# %%
df.cidade.value_counts()
# Out:
# São Paulo                8255
# Rio de Janeiro            163
# Fortaleza                  20
# Campinas                   20
# Recife                     12
# Belo Horizonte             12
# Porto Alegre                8
# Florianopolis               7
# Curitiba                    6
# Goiânia                     5
# Ubatuba                     3
# Cabo Frio                   2
# Santo André                 2
# Foz do Iguaçu               1
# Armação Dos Búzios          1
# Barueri                     1
# Salvador                    1
# Joao Pessoa                 1
# Guarulhos                   1
# São José do Rio Preto       1
# Name: cidade, dtype: int64

# %%
df.bairro.value_counts()
# Out:
# Vila Mariana                        1034
# Paraíso                              824
# Paulista                             810
# Condado - Itaim Bibi                 658
# Higienópolis                         650
# Jardins                              613
# Bela Vista                           496
# Centro                               494
# Vila Olímpia                         377
# Pinheiros                            371
# Perdizes                             318
# Bom Retiro                           203
# Brooklin                             202
# Cerqueira César                      161
# Centro Histórico de São Paulo        115
# Brás                                 115
# Liberdade                            113
# Itaim Bibi                           104
# Jardim Paulista                       93
# Rio de Janeiro                        87
# Consolação                            68
# República                             66
# Sp                                    62
# ...

# %%
df.criacao2.unique()
# Out:
# array(['2021-11-18T00:00:00.000000000', '2021-11-17T00:00:00.000000000',
#        '2021-11-16T00:00:00.000000000', '2021-11-15T00:00:00.000000000',
#        '2021-11-14T00:00:00.000000000', '2021-11-13T00:00:00.000000000',
#        '2021-11-12T00:00:00.000000000', '2021-11-11T00:00:00.000000000',
#        '2021-11-10T00:00:00.000000000', '2021-11-09T00:00:00.000000000',
#        '2021-11-08T00:00:00.000000000', '2021-11-07T00:00:00.000000000',
#        '2021-11-06T00:00:00.000000000', '2021-11-05T00:00:00.000000000',
#        '2021-11-04T00:00:00.000000000', '2021-11-03T00:00:00.000000000',
#        '2021-11-02T00:00:00.000000000', '2021-11-01T00:00:00.000000000',
#        '2021-10-31T00:00:00.000000000', '2021-10-30T00:00:00.000000000',
#        '2021-10-29T00:00:00.000000000', '2021-10-28T00:00:00.000000000',
#        '2021-10-27T00:00:00.000000000', '2021-10-26T00:00:00.000000000',
#        '2021-10-25T00:00:00.000000000', '2021-10-24T00:00:00.000000000',
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28505 entries, 0 to 28546
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   criacao2  28505 non-null  object
# dtypes: object(1)
# memory usage: 1.4+ MB

# %%
data = df[['status', 'isSubscription','cidade', 'bairro', 'guest_email', 'criacao2']]
data.head(10)
# Out:
#      status isSubscription     cidade                bairro  \
# 0  RESERVED           True  São Paulo               Jardins
# 1  RESERVED           True  São Paulo          Vila Mariana
# 2  RESERVED           True  São Paulo  Condado - Itaim Bibi
# 3   EXPIRED           True  São Paulo               Jardins
# 4   EXPIRED          False  São Paulo  Condado - Itaim Bibi
# 5    BOOKED          False  São Paulo  Condado - Itaim Bibi
# 6   EXPIRED          False  São Paulo  Condado - Itaim Bibi
# 7    BOOKED          False  São Paulo          Vila Mariana
# 8    BOOKED           True  São Paulo          Vila Mariana
# 9   EXPIRED          False  São Paulo  Condado - Itaim Bibi
#
#                   guest_email   criacao2
# 0    rogerioslgomes@gmail.com 2021-11-18
# 1  mirian30moraes@hotmail.com 2021-11-18
# 2   adrianoartiaga@uol.com.br 2021-11-18
# 3    rogerioslgomes@gmail.com 2021-11-18
# 4        spodlubn@hotmail.com 2021-11-18
# 5      gabrieloffbz@gmail.com 2021-11-18
# ...

# %%
data.shape
# Out:
# (28505, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28505 entries, 0 to 28546
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   status          28505 non-null  object
#  1   isSubscription  28505 non-null  object
#  2   cidade          8522 non-null   object
#  3   bairro          8522 non-null   object
#  4   guest_email     28505 non-null  object
#  5   criacao2        28505 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 2.5+ MB

# %%
data['bairro'].unique()
# Out:
# array(['Jardins', 'Vila Mariana', 'Condado - Itaim Bibi', 'Paraíso',
#        'Vila Olímpia', 'Centro', 'Bela Vista', 'Perdizes', 'Paulista',
#        'Sp', 'Bom Retiro', 'Jardim das Acacias', 'Pinheiros',
#        'Cidade Monções', 'Rio de Janeiro', 'Itaim Bibi', 'Leme',
#        'Cerqueira César', 'Jardim dos Ipes', 'Indianópolis', 'Brooklin',
#        'Jardim Paulista', 'Leblon', 'Auxiliadora', 'Higienópolis',
#        'Alphaville Industrial', 'Consolação', 'Vila Regente Feijó',
#        'Liberdade', 'Moema', 'República', 'Barra da Tijuca', 'Aclimação',
#        'Vila Madalena', 'Centro Histórico de São Paulo', 'Luz',
#        'Meireles', 'Vila Congonhas', 'Brás', 'Jardim Das Acacias',
#        'Agronômica', 'Brooklin Paulista', 'Berrini', 'Paraná',
#        'Jardim Europa', 'Butantã', 'Cambuí', 'Sion', 'Batel',
#        'Jardim Nova California', 'Sé', 'Vila Homero Thon',
#        'Alto de Pinheiros', 'Vila Romana', 'Mooca', 'Água Verde',
# ...

# %%
data['cidade'].unique()
# Out:
# array(['Sao Paulo', 'São Paulo', 'Flamengo', 'Rio de Janeiro',
#        'Porto Alegre', 'Barueri', 'Fortaleza', 'Guarulhos',
#        'Florianopolis', 'Foz do Iguaçu', 'Campinas', 'Belo Horizonte',
#        'Curitiba', 'Santo André', 'São José do Rio Preto', 'Recife',
#        'Copacabana', 'Goiânia', 'Ubatuba', 'Armação Dos Búzios',
#        'Joao Pessoa', 'Salvador', 'Botafogo', 'Cabo Frio', nan],
#       dtype=object)

# %%
#data.index = pd.to_datetime(data['criacao2'], format='%Y-%m/%d')
#data.groupby(by=[data.index.month, data.index.year])

# %%
#ano_ = data.groupby(pd.Grouper(freq='Y'))
#ano_

# %%
#mes_ = data.groupby(pd.Grouper(freq='M'))

# %%
grouped = data.groupby('status')
grouped

# %%
# visualizando todos os status do data frame

grouped.groups
# Out:
# {'BOOKED': [5, 7, 8, 10, 31, 43, 44, 48, 54, 57, 59, 61, 71, 77, 83, 85, 86, 96, 97, 104, 108, 110, 114, 129, 153, 157, 168, 169, 170, 179, 183, 186, 188, 196, 200, 205, 217, 231, 234, 236, 268, 269, 270, 279, 281, 284, 290, 293, 294, 305, 309, 328, 329, 333, 338, 359, 363, 380, 382, 388, 389, 401, 404, 407, 408, 434, 436, 454, 456, 457, 458, 461, 463, 473, 475, 479, 486, 487, 488, 490, 493, 495, 507, 516, 534, 561, 567, 568, 575, 576, 578, 586, 589, 590, 593, 594, 601, 610, 614, 616, ...], 'BOOKED_MANUALLY': [81, 583, 992, 1111, 1164, 1208, 1572, 1828, 1889, 2377, 2500, 2540, 2745, 2909, 2970, 3044, 3291, 3322, 3327, 3489, 3501, 3753, 3758, 3922, 4411, 4526, 4682, 4734, 4809, 4831, 4868, 4869, 4890, 4995, 5021, 5041, 5131, 5136, 5204, 5210, 5266, 5274, 5284, 5349, 5421, 5423, 5441, 5447, 5471, 5570, 5582, 5722, 5774, 5802, 5832, 5928, 5930, 5975, 5987, 6001, 6170, 6192, 6211, 6228, 6234, 6261, 6290, 6307, 6380, 6506, 6545, 6558, 6559, 6628, 6639, 6719, 6742, 6743, 6885, 6952, 6955, 
# ...

# %%
# Total de linhas com cada status

grouped.size()
# Out:
# status
# BOOKED              3380
# BOOKED_MANUALLY      131
# CANCELED            9513
# EXPIRED            15342
# RESERVED               4
# WAITING_PAYMENT      135
# dtype: int64

# %%
# Visualizando todos os status 'booked'

grouped.get_group('BOOKED')
# Out:
#        status isSubscription     cidade                bairro  \
# 5      BOOKED          False  São Paulo  Condado - Itaim Bibi
# 7      BOOKED          False  São Paulo          Vila Mariana
# 8      BOOKED           True  São Paulo          Vila Mariana
# 10     BOOKED           True  São Paulo               Paraíso
# 31     BOOKED           True  São Paulo               Jardins
# ...       ...            ...        ...                   ...
# 28490  BOOKED          False        NaN                   NaN
# 28508  BOOKED          False        NaN                   NaN
# 28509  BOOKED          False        NaN                   NaN
# 28517  BOOKED          False        NaN                   NaN
# 28546  BOOKED           True  São Paulo       Cerqueira César
#
#                           guest_email    criacao2
# 5              gabrieloffbz@gmail.com  2021-11-18
# 7             wanderbezerra@gmail.com  2021-11-18
# 8             rafaelakoury@icloud.com  2021-11-18
# ...

# %%
# Total de 'booked' e 'booked_manually'

data.groupby(data['status'].apply(lambda x: 'BOOKED' in x)).size()
# Out:
# status
# False    24994
# True      3511
# dtype: int64

# %%
pd.options.display.max_rows = 86
data[['bairro','isSubscription']].groupby('bairro').count().sort_values(by='isSubscription', ascending=False)
# Out:
#                                   isSubscription
# bairro
# Vila Mariana                                1034
# Paraíso                                      824
# Paulista                                     810
# Condado - Itaim Bibi                         658
# Higienópolis                                 650
# Jardins                                      613
# Bela Vista                                   496
# Centro                                       494
# Vila Olímpia                                 377
# Pinheiros                                    371
# Perdizes                                     318
# Bom Retiro                                   203
# Brooklin                                     202
# Cerqueira César                              161
# Centro Histórico de São Paulo                115
# Brás                                         115
# Liberdade                                    113
# Itaim Bibi                                   104
# ...

# %%
data[['bairro','isSubscription']].groupby(['bairro','isSubscription']).count().sort_values(by='isSubscription', ascending=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Higienópolis, True), (Flamengo, True), (Vila Mariana, True), (Perdizes, True), (Paulista, True), (Paraíso, True), (Liberdade, True), (Jardins, True), (Bela Vista, True), (Vila Olímpia, True), (Consolação, True), (Condado - Itaim Bibi, True), (Centro, True), (Butantã, True), (Brooklin, True), (Bom Retiro, True), (Jardins, False), (Leblon, False), (Centro, False), (Bom Retiro, False), (Vila Olímpia, False), (Bela Vista, False)]

# %%
data[['bairro', 'email', 'isSubscription']].groupby(['bairro','email'],as_index=False).agg({'isSubscription':'size'})
# Out:
#                   bairro                             email  isSubscription
# 0             Bela Vista            ag_romera@yahoo.com.br               1
# 1             Bela Vista         alexxcorrea1995@gmail.com               3
# 2             Bela Vista              camisalees@gmail.com               2
# 3             Bela Vista  comercialthalyadasilva@gmail.com               2
# 4             Bela Vista             fagundesph1@gmail.com               2
# 5             Bela Vista               ivanpr1me@gmail.com               3
# 6             Bela Vista                 matnora@gmail.com               4
# 7             Bela Vista           mauropaladini@gmail.com               2
# 8             Bela Vista            natudedytrip@gmail.com               1
# 9             Bela Vista                rqlmaia1@gmail.com               1
# 10            Bela Vista         sara.al.silva@hotmail.com               2
# ...

# %%
df_tsubscpt = data[(data.isSubscription == True)]
#pd.options.display.max_rows = 66
df_tsubscpt
# Out:
#          status isSubscription     cidade                bairro  \
# 0      RESERVED           True  São Paulo               Jardins
# 1      RESERVED           True  São Paulo          Vila Mariana
# 2      RESERVED           True  São Paulo  Condado - Itaim Bibi
# 3       EXPIRED           True  São Paulo               Jardins
# 8        BOOKED           True  São Paulo          Vila Mariana
# ...         ...            ...        ...                   ...
# 28459    BOOKED           True        NaN                   NaN
# 28467  CANCELED           True        NaN                   NaN
# 28518  CANCELED           True        NaN                   NaN
# 28532  CANCELED           True        NaN                   NaN
# 28546    BOOKED           True  São Paulo       Cerqueira César
#
#                       guest_email    criacao2
# 0        rogerioslgomes@gmail.com  2021-11-18
# 1      mirian30moraes@hotmail.com  2021-11-18
# 2       adrianoartiaga@uol.com.br  2021-11-18
# ...

# %%
#bairros com mais assinaturas.

df_tsubscpt[['bairro','isSubscription']].groupby('bairro').count().sort_values(by='isSubscription', ascending=False)
# Out:
#                                  isSubscription
# bairro
# Vila Mariana                                764
# Paraíso                                     694
# Higienópolis                                602
# Paulista                                    493
# Centro                                      423
# Condado - Itaim Bibi                        417
# Bela Vista                                  377
# Jardins                                     280
# Vila Olímpia                                257
# Perdizes                                    237
# Bom Retiro                                  192
# Pinheiros                                   192
# Brooklin                                    147
# Cerqueira César                             134
# Liberdade                                    84
# Itaim Bibi                                   59
# República                                    58
# Jardim Paulista                              54
# ...

# %%
df_tsubscpt[['guest_email','isSubscription']].groupby('guest_email').count().sort_values(by='isSubscription', ascending=False)
# Out:
#                               isSubscription
# guest_email
# tester@housi.com.br                       97
# edgar.thina@hotmail.com                   69
# souzajonas@outlook.com                    69
# cassiuscatarina@gmail.com                 63
# guirosasoares@gmail.com                   57
# ...                                      ...
# lorenaplobo@gmail.com                      1
# lorenaslopes@hotmail.com                   1
# deborahamoedo@hotmail.com                  1
# deborah1deborah123@gmail.com               1
# julianescatolao@hotmail.com                1
#
# [5753 rows x 1 columns]

# %%
df_tsubscpt.groupby("guest_email", dropna=False).agg('count')
# Out:
#                            status  isSubscription  cidade  bairro  criacao2
# guest_email
# 111222lucas@gmail.com           2               2       1       1         2
# 1994ericam@gmail.com            3               3       0       0         3
# 4419970@gmail.com               2               2       0       0         2
# a.vieira13@hotmail.com.br       2               2       0       0         2
# a_bomfim@hotmail.com            1               1       0       0         1
# ...                           ...             ...     ...     ...       ...
# zhu1984@gmail.com               1               1       0       0         1
# zinamonizza@gmail.com           1               1       1       1         1
# zinhoconta@gmail.com           10              10       0       0        10
# zrcastr@hotmail.com             1               1       1       1         1
# zrcastro@hotmail.com            5               5       5       5         5
#
# [5753 rows x 5 columns]

# %%
stgroup = df_tsubscpt.groupby(by=['guest_email'])['status'].apply(list)
stgroup
# Out:
# guest_email
# 111222lucas@gmail.com                                       [EXPIRED, EXPIRED]
# 1994ericam@gmail.com                            [CANCELED, CANCELED, CANCELED]
# 4419970@gmail.com                                         [CANCELED, CANCELED]
# a.vieira13@hotmail.com.br                                 [CANCELED, CANCELED]
# a_bomfim@hotmail.com                                                 [EXPIRED]
#                                                    ...
# zhu1984@gmail.com                                                     [BOOKED]
# zinamonizza@gmail.com                                                [EXPIRED]
# zinhoconta@gmail.com         [EXPIRED, EXPIRED, EXPIRED, EXPIRED, EXPIRED, ...
# zrcastr@hotmail.com                                                   [BOOKED]
# zrcastro@hotmail.com             [EXPIRED, EXPIRED, EXPIRED, EXPIRED, EXPIRED]
# Name: status, Length: 5753, dtype: object

# %%
grouped = df.groupby('Sales Rep')
grouped

# %%
subscpt_b = df_tsubscpt.groupby(by=['bairro'])['isSubscription'].apply(list)
subscpt_b
# Out:
# bairro
# Bela Vista              [True, True, True, True, True, True, True, Tru...
# Bom Retiro                                                         [True]
# Brooklin                                               [True, True, True]
# Butantã                                                      [True, True]
# Centro                                                       [True, True]
# Condado - Itaim Bibi                                         [True, True]
# Consolação                                                         [True]
# Flamengo                                                           [True]
# Higienópolis                         [True, True, True, True, True, True]
# Jardins                                          [True, True, True, True]
# Liberdade                                                          [True]
# Paraíso                  [True, True, True, True, True, True, True, True]
# Paulista                                                           [True]
# ...

# %%
subscpt_b[0]
# Out:
# [True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
hg = df[(df.bairro == 'Higienópolis') & (df.isSubscription)]
hg
# Out:
#     Unnamed: 0   status  channel  isSubscription                       _id  \
# 28          31   BOOKED     SITE            True  613bd1763bb0970018fdc9f2
# 36          41  EXPIRED  COCKPIT            True  613bb01fea924f001230f2ef
# 46          53  EXPIRED     SITE            True  613ba147ea924f001230d8d3
# 60          68  EXPIRED  COCKPIT            True  613b704eea924f00122e535d
# 82          94  EXPIRED     SITE            True  613acdedea924f00122dc234
# 84          96  EXPIRED     SITE            True  613ac813ea924f00122dc13a
#
#    aliasId                   staysId   createdAt   updatedAt  \
# 28  XC307G  613bd175f0266647ec1cdecb  09/10/2021  10/09/2021
# 36   XD81G  613bb01ff02666ce5e1cdbee  09/10/2021  11/09/2021
# 46   XD80G  613ba147f0266667b11cd864  09/10/2021  10/09/2021
# 60   XD79G  613b704ef02666d8e11cd406  09/10/2021  11/09/2021
# 82   XD76G  613acdec2849b5801a83bda0  09/10/2021  10/09/2021
# 84   XD75G  613ac813258ec19d3c1386dd  09/10/2021  10/09/2021
#
# ...
