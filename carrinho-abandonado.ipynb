# %%
import pandas as pd
import json
import requests

# %%
# for i in range (1, 21)
#url_reserva = 'https://booking.onhousi.com/reservations?token=5b1f1f4bf68208cfe93445c034072df0c5e50002&page={}&limit=100'.format

# %%
#data = []

# %%
#for items in range(1,50):
#    url = 'https://booking.onhousi.com/reservations?token=5b1f1f4bf68208cfe93445c034072df0c5e50002&page={}&limit=100'.format(items)
#     res = requests.get(url)
#    data = json.loads(res.text)['items']
#    for x in range(0,100):
#        uni = {}
#        try:
#            items['aliasId'] = uni['reserva']
#        except:
#            pass
#        try:
#            items['status'] = uni['status']
#        except:
#            pass
#        try:
#            items['channel'] = uni['channel']
#        except:
#            pass
#        try:
#            items['property']['aliasID'] = uni['aliasID']
#        except:
#        try:
#            items['property']['name'] = uni['name_un']
#        except:
#            pass
#        try:
#            items['checkIn']['date'] = uni['checkIn']
#        except:
#            pass
#        try:
#            items['checkOut']['date'] = uni['checkOut']
#        except:
            pass
        try:
            items['user']['email'] = uni['email']
        except:
            pass
        try:
            items['user']['firstName'] = uni['firstName']
        except:
            pass
        try:
            items['createdAt'] = uni['createdAt']
        except:
            pass
        try:
            items['total']['amount'][''] = uni['valor']
        except:
            pass
        data.append(uni)

# %%
df = pd.DataFrame(data)
df
# Out:
#       status channel isSubscription hubServices                       _id  \
# 0     BOOKED    SITE           True          []  613c425c3bb0970018fe5e28
# 1    EXPIRED    SITE           True          []  613c392b3bb0970018fe5dc0
# 2    EXPIRED     APP          False          []  613c38e63bb0970018fe5da0
# 3    EXPIRED    SITE           True          []  613c2c6b3bb0970018fe4cc2
# 4    EXPIRED    SITE           True          []  613c27c13bb0970018fe4c6b
# ..       ...     ...            ...         ...                       ...
# 195      NaN     NaN            NaN         NaN                       NaN
# 196      NaN     NaN            NaN         NaN                       NaN
# 197      NaN     NaN            NaN         NaN                       NaN
# 198      NaN     NaN            NaN         NaN                       NaN
# 199      NaN     NaN            NaN         NaN                       NaN
#
#                                               property  \
# ...

# %%
df.to_csv('carrinho_abandonado.csv')
