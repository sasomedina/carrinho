# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df = pd.read_excel(r'tabela_carrinho_abandonado.xlsx')
display(df)
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1           status channel  \
# 0            0             0               0           BOOKED    SITE
# 1            1             1               1          EXPIRED    SITE
# 2            2             2               2          EXPIRED     APP
# 3            3             3               3          EXPIRED    SITE
# 4            4             4               4          EXPIRED    SITE
# ..         ...           ...             ...              ...     ...
# 95          95            95              95          EXPIRED     APP
# 96          96            96              96          EXPIRED    SITE
# 97          97            97              97  WAITING_PAYMENT    SITE
# 98          98            98              98           BOOKED     APP
# 99          99            99              99          EXPIRED     APP
#
#     isSubscription                       _id aliasId  \
# 0             True  613c425c3bb0970018fe5e28   WO60G
# ...

# %%
pd.options.display.max_columns = 104
df
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1           status channel  \
# 0            0             0               0           BOOKED    SITE
# 1            1             1               1          EXPIRED    SITE
# 2            2             2               2          EXPIRED     APP
# 3            3             3               3          EXPIRED    SITE
# 4            4             4               4          EXPIRED    SITE
# ..         ...           ...             ...              ...     ...
# 95          95            95              95          EXPIRED     APP
# 96          96            96              96          EXPIRED    SITE
# 97          97            97              97  WAITING_PAYMENT    SITE
# 98          98            98              98           BOOKED     APP
# 99          99            99              99          EXPIRED     APP
#
#     isSubscription                       _id aliasId  \
# 0             True  613c425c3bb0970018fe5e28   WO60G
# ...

# %%
display(df[['createdAt', 'updatedAt', 'data_checkin', 'data_checkout', 'data_status_1', 'data_status_2']])
# Out:
#                    createdAt                 updatedAt data_checkin  \
# 0   2021-09-11T05:45:00.318Z  2021-09-11T05:47:23.534Z   2021-09-17
# 1   2021-09-11T05:05:47.239Z  2021-09-11T05:11:03.201Z   2021-09-17
# 2   2021-09-11T05:04:38.217Z  2021-09-11T05:10:08.161Z   2021-09-19
# 3   2021-09-11T04:11:23.608Z  2021-09-11T04:17:07.480Z   2021-09-23
# 4   2021-09-11T03:51:29.732Z  2021-09-11T03:57:12.673Z   2021-11-18
# ..                       ...                       ...          ...
# 95  2021-09-10T03:03:19.636Z  2021-09-10T03:09:07.044Z   2021-09-20
# 96  2021-09-10T02:50:59.719Z  2021-09-10T02:56:08.679Z   2021-10-02
# 97  2021-09-10T02:23:17.952Z  2021-09-10T02:23:43.632Z   2021-09-11
# 98  2021-09-10T02:08:24.439Z  2021-09-10T02:08:32.241Z   2021-10-02
# 99  2021-09-10T02:02:03.060Z  2021-09-10T02:07:09.903Z   2021-10-02
#
#    data_checkout             data_status_1             data_status_2
# 0     2021-10-17  2021-09-11T05:47:23.534Z  2021-09-11T05:47:23.523Z
# ...

# %%
df[['createdAt', 'updatedAt', 'data_checkin', 'data_checkout', 'data_status_1', 'data_status_2']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   createdAt      100 non-null    object
#  1   updatedAt      100 non-null    object
#  2   data_checkin   100 non-null    object
#  3   data_checkout  100 non-null    object
#  4   data_status_1  100 non-null    object
#  5   data_status_2  100 non-null    object
# dtypes: object(6)
# memory usage: 4.8+ KB

# %%
df['createdAt'] = df['createdAt'].dt.date

# %%
df['updatedAt'] = pd.to_datetime(df['updatedAt'], errors='coerce')
df['data_status_1'] = pd.to_datetime(df['data_status_1'], errors='coerce')
df['data_status_2'] = pd.to_datetime(df['data_status_2'], errors='coerce')

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 102 columns):
#  #    Column                   Dtype
# ---   ------                   -----
#  0    Unnamed: 0               int64
#  1    status                   object
#  2    channel                  object
#  3    isSubscription           bool
#  4    _id                      object
#  5    aliasId                  object
#  6    staysId                  object
#  7    createdAt                datetime64[ns, UTC]
#  8    updatedAt                datetime64[ns, UTC]
#  9    id_property              object
#  10   id_alias                 object
#  11   external_id              object
#  12   nome_property            object
#  13   alias_property           object
#  14   main_photo               object
#  15   id_cidade                object
#  16   cidade                   object
#  17   id_bairro                object
#  18   bairro                   object
# ...

# %%
pd.options.display.max_columns = 104
df.head()
# Out:
#    Unnamed: 0   status channel  isSubscription                       _id  \
# 0           0   BOOKED    SITE            True  613c425c3bb0970018fe5e28
# 1           1  EXPIRED    SITE            True  613c392b3bb0970018fe5dc0
# 2           2  EXPIRED     APP           False  613c38e63bb0970018fe5da0
# 3           3  EXPIRED    SITE            True  613c2c6b3bb0970018fe4cc2
# 4           4  EXPIRED    SITE            True  613c27c13bb0970018fe4c6b
#
#   aliasId                   staysId                        createdAt  \
# 0   WO60G  613c425b7e3cb113b0501e66 2021-09-11 05:45:00.318000+00:00
# 1   WO59G  613c392a04b00a7460d739a8 2021-09-11 05:05:47.239000+00:00
# 2   WQ50G  613c38e5f02666a9301cee49 2021-09-11 05:04:38.217000+00:00
# 3  TE8D4P                       NaN 2021-09-11 04:11:23.608000+00:00
# 4   YY16G  613c27c1af7781c693f73a7c 2021-09-11 03:51:29.732000+00:00
#
#                          updatedAt               id_property id_alias  \
# ...

# %%
#df.to_excel('tabela_carrinho_abandonado.xlsx')

# %%
df = pd.read_excel(r'tabela_carrinho_abandonado.xlsx')
display(df.head())
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   status channel  isSubscription  \
# 0           0             0               0   BOOKED    SITE            True
# 1           1             1               1  EXPIRED    SITE            True
# 2           2             2               2  EXPIRED     APP           False
# 3           3             3               3  EXPIRED    SITE            True
# 4           4             4               4  EXPIRED    SITE            True
#
#                         _id aliasId                   staysId  \
# 0  613c425c3bb0970018fe5e28   WO60G  613c425b7e3cb113b0501e66
# 1  613c392b3bb0970018fe5dc0   WO59G  613c392a04b00a7460d739a8
# 2  613c38e63bb0970018fe5da0   WQ50G  613c38e5f02666a9301cee49
# 3  613c2c6b3bb0970018fe4cc2  TE8D4P                       NaN
# 4  613c27c13bb0970018fe4c6b   YY16G  613c27c1af7781c693f73a7c
#
#                   createdAt                 updatedAt  \
# 0  2021-09-11T05:45:00.318Z  2021-09-11T05:47:23.534Z
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 104 columns):
#  #    Column                   Dtype
# ---   ------                   -----
#  0    Unnamed: 0               int64
#  1    Unnamed: 0.1             int64
#  2    Unnamed: 0.1.1           int64
#  3    status                   object
#  4    channel                  object
#  5    isSubscription           bool
#  6    _id                      object
#  7    aliasId                  object
#  8    staysId                  object
#  9    createdAt                object
#  10   updatedAt                object
#  11   id_property              object
#  12   id_alias                 object
#  13   external_id              object
#  14   nome_property            object
#  15   alias_property           object
#  16   main_photo               object
#  17   id_cidade                object
#  18   cidade                   object
#  19   id_bairro                object
# ...

# %%
df = df.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0.1.1'])
df.head()
# Out:
#    Unnamed: 0   status channel  isSubscription                       _id  \
# 0           0   BOOKED    SITE            True  613c425c3bb0970018fe5e28
# 1           1  EXPIRED    SITE            True  613c392b3bb0970018fe5dc0
# 2           2  EXPIRED     APP           False  613c38e63bb0970018fe5da0
# 3           3  EXPIRED    SITE            True  613c2c6b3bb0970018fe4cc2
# 4           4  EXPIRED    SITE            True  613c27c13bb0970018fe4c6b
#
#   aliasId                   staysId                 createdAt  \
# 0   WO60G  613c425b7e3cb113b0501e66  2021-09-11T05:45:00.318Z
# 1   WO59G  613c392a04b00a7460d739a8  2021-09-11T05:05:47.239Z
# 2   WQ50G  613c38e5f02666a9301cee49  2021-09-11T05:04:38.217Z
# 3  TE8D4P                       NaN  2021-09-11T04:11:23.608Z
# 4   YY16G  613c27c1af7781c693f73a7c  2021-09-11T03:51:29.732Z
#
#                   updatedAt               id_property id_alias  \
# 0  2021-09-11T05:47:23.534Z  60184c355926f200120943a0    IN06G
# ...

# %%
df['createdAt'] = pd.to_datetime(df['createdAt'], errors='coerce')
df['updatedAt'] = pd.to_datetime(df['updatedAt'], errors='coerce')
df['data_checkin'] = pd.to_datetime(df['data_checkin'], errors='coerce')
df['data_checkout'] = pd.to_datetime(df['data_checkout'], errors='coerce')
df['data_status_1'] = pd.to_datetime(df['data_status_1'], errors='coerce')
df['data_status_2'] = pd.to_datetime(df['data_status_2'], errors='coerce')

# %%
import datetime

df['createdAt'] = df['createdAt'].dt.date
df['updatedAt'] = df['updatedAt'].dt.date
df['data_checkin'] = df['data_checkin'].dt.date
df['data_checkout'] = df['data_checkout'].dt.date
df['data_status_1'] = df['data_status_1'].dt.date
df['data_status_2'] = df['data_status_2'].dt.date

# %%
df['createdAt'] = pd.to_datetime(df['createdAt'], errors='coerce')
df['updatedAt'] = pd.to_datetime(df['updatedAt'], errors='coerce')
df['data_checkin'] = pd.to_datetime(df['data_checkin'], errors='coerce')
df['data_checkout'] = pd.to_datetime(df['data_checkout'], errors='coerce')
df['data_status_1'] = pd.to_datetime(df['data_status_1'], errors='coerce')
df['data_status_2'] = pd.to_datetime(df['data_status_2'], errors='coerce')

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 104 columns):
#  #    Column                   Dtype
# ---   ------                   -----
#  0    Unnamed: 0               int64
#  1    Unnamed: 0.1             int64
#  2    Unnamed: 0.1.1           int64
#  3    status                   object
#  4    channel                  object
#  5    isSubscription           bool
#  6    _id                      object
#  7    aliasId                  object
#  8    staysId                  object
#  9    createdAt                datetime64[ns]
#  10   updatedAt                datetime64[ns]
#  11   id_property              object
#  12   id_alias                 object
#  13   external_id              object
#  14   nome_property            object
#  15   alias_property           object
#  16   main_photo               object
#  17   id_cidade                object
#  18   cidade                   object
#  19   id_bairro                object
# ...

# %%
df['createdAt'] = df['createdAt'].apply(lambda x: x.strftime('%d/%m/%Y'))
df['updatedAt'] = df['updatedAt'].apply(lambda x: x.strftime('%d/%m/%Y'))
df['data_checkin'] = df['data_checkin'].apply(lambda x: x.strftime('%d/%m/%Y'))
df['data_checkout'] = df['data_checkout'].apply(lambda x: x.strftime('%d/%m/%Y'))
df['data_status_1'] = df['data_status_1'].apply(lambda x: x.strftime('%d/%m/%Y'))
df['data_status_2'] = df['data_status_2'].apply(lambda x: x.strftime('%d/%m/%Y'))

# %%
display(df['createdAt'])
# Out:
# 0     09/11/2021
# 1     09/11/2021
# 2     09/11/2021
# 3     09/11/2021
# 4     09/11/2021
#          ...
# 95    09/10/2021
# 96    09/10/2021
# 97    09/10/2021
# 98    09/10/2021
# 99    09/10/2021
# Name: createdAt, Length: 100, dtype: object

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1   status channel  isSubscription  \
# 0           0             0               0   BOOKED    SITE            True
# 1           1             1               1  EXPIRED    SITE            True
# 2           2             2               2  EXPIRED     APP           False
# 3           3             3               3  EXPIRED    SITE            True
# 4           4             4               4  EXPIRED    SITE            True
#
#                         _id aliasId                   staysId   createdAt  \
# 0  613c425c3bb0970018fe5e28   WO60G  613c425b7e3cb113b0501e66  09/11/2021
# 1  613c392b3bb0970018fe5dc0   WO59G  613c392a04b00a7460d739a8  09/11/2021
# 2  613c38e63bb0970018fe5da0   WQ50G  613c38e5f02666a9301cee49  09/11/2021
# 3  613c2c6b3bb0970018fe4cc2  TE8D4P                       NaN  09/11/2021
# 4  613c27c13bb0970018fe4c6b   YY16G  613c27c1af7781c693f73a7c  09/11/2021
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0   status channel  isSubscription                       _id  \
# 0           0   BOOKED    SITE            True  613c425c3bb0970018fe5e28
# 1           1  EXPIRED    SITE            True  613c392b3bb0970018fe5dc0
# 2           2  EXPIRED     APP           False  613c38e63bb0970018fe5da0
# 3           3  EXPIRED    SITE            True  613c2c6b3bb0970018fe4cc2
# 4           4  EXPIRED    SITE            True  613c27c13bb0970018fe4c6b
#
#   aliasId                   staysId   createdAt   updatedAt  \
# 0   WO60G  613c425b7e3cb113b0501e66  11/09/2021  11/09/2021
# 1   WO59G  613c392a04b00a7460d739a8  11/09/2021  11/09/2021
# 2   WQ50G  613c38e5f02666a9301cee49  11/09/2021  11/09/2021
# 3  TE8D4P                       NaN  11/09/2021  11/09/2021
# 4   YY16G  613c27c1af7781c693f73a7c  11/09/2021  11/09/2021
#
#                 id_property id_alias                external_id  \
# 0  60184c355926f200120943a0    IN06G   5f63c47c64c2a05c5bdb0cd9
# ...

# %%
df.to_excel('tabela_carrinho_abandonado.xlsx')
